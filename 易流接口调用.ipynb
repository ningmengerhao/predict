# %%
import requests
from datetime import datetime
import hashlib
datetime.now().strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2022-10-07 10:32:54'

# %%
params = {
    'appkey' : '1BE14988-A0AC-4200-B41A-8220B976B65B',
    'method':'GetTrackDetail',
    'timestamp':datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
    'format': 'json',
    'isoffsetlonlat':1,
    'isplacename':1,
    'btime':'2022-09-21 21:00:00',
    'etime':'2012-09-22 8:00:00'
}
# r = requests.get('https://api.e6yun.com/public/v3/StatisticsReport/Call',params=params)



hashlib.md5('184CD4DF-C5D2-4F55-8539-ED45D4E91FBBappkeyabe10b89-8185-483a-b28f-894f7957f78dformatjsonmethodGetVehcileInfosessionidtimestamp2014-11-08 11:47:42vehicle陕A0000184CD4DF-C5D2-4F55-8539-ED45D4E91FBB'.encode()).hexdigest().upper()
# Out:
# 'FB9C769546B8129B3F765A99ACDFFDCA'

# %%
x = {'x': 20, 'a': 12, 'b': 5}
# Out:
# dict_keys(['x', 'a', 'b'])

# %%
import pandas as pd
df = pd.read_clipboard()
df['关键字'] = df['门店名称'].str.extract(r'^南京(.*?)店')

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import plot_roc_curve
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt
import sklearn

X, y = make_classification(random_state=0)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

svc = SVC(random_state=42)
svc.fit(X_train, y_train)
rfc = RandomForestClassifier(random_state=42)
rfc.fit(X_train, y_train)


svc_disp = plot_roc_curve(svc, X_test, y_test)
rfc_disp = plot_roc_curve(rfc, X_test, y_test, ax=svc_disp.ax_)
rfc_disp.figure_.suptitle("ROC curve comparison")

plt.show()
# Out:
# c:\Users\6433\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)
# c:\Users\6433\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)

# %%
import pandas as pd
df = pd.read_clipboard()
df
columns = [i for i in df.columns.values if i.startswith("车型")]

# %%
df['ColumnA'] = df[columns].apply(
    lambda x: ','.join(x.dropna()),
    axis=1)   # ”1:“表示合并第一列之后的各列为一列

# %%
df
# Out:
#             日期 目的地  4.2  7.6  9.6   车型    车型.1    车型.2        ColumnA
# 0     2022/9/1  合肥  NaN  NaN  2.0  NaN     NaN  2辆L096         2辆L096
# 1     2022/9/1  南京  NaN  NaN  4.0  NaN     NaN  4辆L096         4辆L096
# 2     2022/9/1  南通  NaN  2.0  NaN  NaN  2辆L076     NaN         2辆L076
# 3     2022/9/1  上海  NaN  NaN  6.0  NaN     NaN  6辆L096         6辆L096
# 4     2022/9/1  苏州  NaN  NaN  2.0  NaN     NaN  2辆L096         2辆L096
# ..         ...  ..  ...  ...  ...  ...     ...     ...            ...
# 175  2022/9/30  南京  NaN  NaN  4.0  NaN     NaN  4辆L096         4辆L096
# 176  2022/9/30  南通  NaN  NaN  2.0  NaN     NaN  2辆L096         2辆L096
# 177  2022/9/30  上海  NaN  1.0  6.0  NaN  1辆L076  6辆L096  1辆L076,6辆L096
# 178  2022/9/30  苏州  NaN  NaN  3.0  NaN     NaN  3辆L096         3辆L096
# 179  2022/9/30  无锡  NaN  1.0  1.0  NaN  1辆L076  1辆L096  1辆L076,1辆L096
#
# [180 rows x 9 columns]

# %%
df.to_clipboard()

# %%
predict = pd.read_clipboard()
predict = predict.set_index(['配送日期'])
predict
# Out:
#                        南京              上海              合肥              苏州  \
# 配送日期
# 2022/9/1   3辆L076, 1辆L096  1辆L042, 4辆L096  1辆L076, 1辆L096  1辆L076, 1辆L096
# 2022/9/2   2辆L076, 2辆L096          5辆L096  1辆L076, 1辆L096          2辆L096
# 2022/9/3   3辆L076, 1辆L096  1辆L076, 4辆L096          2辆L076          2辆L096
# 2022/9/4   1辆L076, 2辆L096  1辆L042, 4辆L096  1辆L042, 1辆L096          2辆L076
# 2022/9/5   3辆L076, 1辆L096  3辆L076, 2辆L096          2辆L076          2辆L076
# 2022/9/6           3辆L096          4辆L096  1辆L042, 1辆L096          2辆L076
# 2022/9/7   3辆L076, 1辆L096          4辆L096          2辆L076          2辆L076
# 2022/9/8   2辆L076, 2辆L096  1辆L076, 4辆L096          2辆L076  1辆L076, 1辆L096
# 2022/9/9   2辆L076, 2辆L096  1辆L076, 4辆L096  1辆L076, 1辆L096          2辆L096
# 2022/9/10  1辆L042, 3辆L096  1辆L076, 4辆L096          2辆L076  1辆L076, 1辆L096
# 2022/9/11          3辆L096  3辆L076, 2辆L096          2辆L076          2辆L076
# 2022/9/12  3辆L076, 1辆L096  3辆L076, 2辆L096          2辆L076  1辆L076, 1辆L096
# ...

# %%
df3 = predict.stack().to_frame()

# %%
df3[7.6] = df3[0].str.extract(r'(\d)辆L076')
df3[9.6] = df3[0].str.extract(r'(\d)辆L096')
df3[4.2] = df3[0].str.extract(r'(\d)辆L042')
df5 = df3.fillna(0).astype('int',errors='ignore')
df5['容纳框数'] = df5[7.6]*560+df5[9.6]*760+df5[4.2]*190
df5['单公里成本']= df5[7.6]*7.4+df5[9.6]*6+df5[4.2]*4.2
df5.to_clipboard()

# %%
TrunkPredict = Oracle.read("""SELECT
                            POSTING_DATE as 业务日期,
                            LINE_NAME 线路名称,
                            TRUE 转换框数,
                            PREDICT 预测框数,
                            ADVICE 建议方案
                        FROM
                            ZCB_PREDICT_GX_KS
                        ORDER BY
                            LINE_NAME,
                            POSTING_DATE""")


TrunkPredict.set_index('业务日期', inplace=True)
# Out:
#              线路名称   转换框数     预测框数    建议方案
# 业务日期
# 2022-06-14  灌云-淮安  491.0  527.977  1辆L076
# 2022-06-15  灌云-淮安  551.0  509.419  1辆L076
# 2022-06-16  灌云-淮安  590.0  529.447  1辆L096
# 2022-06-17  灌云-淮安  621.0  634.164  1辆L096
# 2022-06-18  灌云-淮安  614.0  647.082  1辆L096
# ...           ...    ...      ...     ...
# 2022-08-07  郑州到西安    NaN  275.711  1辆L076
# 2022-08-08  郑州到西安    NaN  199.900  1辆L076
# 2022-08-09  郑州到西安    NaN  228.908  1辆L042
# 2022-08-10  郑州到西安    NaN  225.780  1辆L042
# 2022-08-11  郑州到西安    NaN  262.604  1辆L076
#
# [2412 rows x 4 columns]

# %%
TrunkPredict.pivot(columns=['线路名称'],values=['建议方案']).to_clipboard()
